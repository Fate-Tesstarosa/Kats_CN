# %%
# !pip install kats
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Looking in indexes: https://mirrors.aliyun.com/pypi/simple
# Collecting kats
#   Downloading https://mirrors.aliyun.com/pypi/packages/51/7a/96933023745c6d6660e2b0b13ae1c0fe236e89acb420a24f15b2519b5f7c/kats-0.1.0.tar.gz (6.3 MB)
#      |████████████████████████████████| 6.3 MB 6.7 MB/s eta 0:00:01
# Collecting LunarCalendar>=0.0.9
#   Downloading https://mirrors.aliyun.com/pypi/packages/ab/e0/a52ffc02395474858552ca6437226e23ad67e25fd85cb387f02e479cfe01/LunarCalendar-0.0.9-py2.py3-none-any.whl (18 kB)
# Requirement already satisfied: attrs>=21.2.0 in /home/yolov5test/.local/lib/python3.8/site-packages (from kats) (21.2.0)
# Collecting ax-platform
#   Downloading https://mirrors.aliyun.com/pypi/packages/9e/38/e3721b5786dc42608018c147e3cd6cdffd79691dc6949693878ed6b5047a/ax_platform-0.2.1-py3-none-any.whl (844 kB)
#      |████████████████████████████████| 844 kB 449 kB/s eta 0:00:01
# Collecting convertdate>=2.1.2
#   Downloading https://mirrors.aliyun.com/pypi/packages/1b/fa/b5f5d8b3a328c930a190540231fe79e854a416df62c57329630823f3941e/convertdate-2.3.2-py3-none-any.whl (47 kB)
#      |████████████████████████████████| 47 kB 16.9 MB/s eta 0:00:01
# Collecting fbprophet==0.7
#   Downloading https://mirrors.aliyun.com/pypi/packages/7a/25/fd432f7dc67f604e509ca29c613ad7502123345501836323d8100be80ce9/fbprophet-0.7.tar.gz (64 kB)
#      |████████████████████████████████| 64 kB 5.5 MB/s eta 0:00:011
# Collecting gpytorch
#   Downloading https://mirrors.aliyun.com/pypi/packages/4a/fa/b6db02ee0e98e89752bdae11534034251bc08317cdc325dd1878732b152d/gpytorch-1.5.0-py2.py3-none-any.whl (498 kB)
#      |████████████████████████████████| 498 kB 7.0 MB/s eta 0:00:01
# Collecting holidays>=0.10.2
#   Downloading https://mirrors.aliyun.com/pypi/packages/c6/2f/fdf23acdcdf2c87c5358fdbba091d27a5ef0cc15ad233ff6f260d9d471ee/holidays-0.11.2-py3-none-any.whl (142 kB)
#      |████████████████████████████████| 142 kB 11.8 MB/s eta 0:00:01
# Requirement already satisfied: matplotlib>=2.0.0 in /home/yolov5test/.local/lib/python3.8/site-packages (from kats) (3.4.2)
# Requirement already satisfied: numpy>=1.15.4 in /home/yolov5test/.local/lib/python3.8/site-packages (from kats) (1.19.5)
# Collecting numba>=0.52.0
#   Downloading https://mirrors.aliyun.com/pypi/packages/f2/e9/cfcbf8c85d99cbdb68619c4c78f3d76d5f5e4829c5f2534422dcd960d355/numba-0.53.1-cp38-cp38-manylinux2014_x86_64.whl (3.4 MB)
#      |████████████████████████████████| 3.4 MB 16.9 MB/s eta 0:00:01
# Requirement already satisfied: pandas>=1.0.4 in /home/yolov5test/.local/lib/python3.8/site-packages (from kats) (1.3.0)
# Collecting plotly>=4.14.3
#   Downloading https://mirrors.aliyun.com/pypi/packages/56/0f/b89786ebda81c7994e11066024ffa4b6c4d97edc1dca02ede22578a77b66/plotly-5.2.1-py2.py3-none-any.whl (21.8 MB)
#      |████████████████████████████████| 21.8 MB 5.7 MB/s eta 0:00:011
# Collecting pymannkendall>=1.4.1
#   Downloading https://mirrors.aliyun.com/pypi/packages/03/72/7eeda485b586ddaaa274225bb2aa365f3a24c94790283d7c230bcecbb28e/pymannkendall-1.4.2-py3-none-any.whl (12 kB)
# Collecting pystan==2.19.1.1
#   Downloading https://mirrors.aliyun.com/pypi/packages/05/02/cab8f6c9c171eae62b74049fce07d431c2033e9d6d7b068695d2ca7d7f3d/pystan-2.19.1.1-cp38-cp38-manylinux1_x86_64.whl (62.6 MB)
#      |████████████████████████████████| 62.6 MB 5.8 MB/s eta 0:00:011
# Requirement already satisfied: python-dateutil>=2.8.0 in /home/yolov5test/.local/lib/python3.8/site-packages (from kats) (2.8.1)
# Requirement already satisfied: scikit-learn>+0.24.2 in /home/yolov5test/.local/lib/python3.8/site-packages (from kats) (0.24.2)
# Requirement already satisfied: setuptools-git>=1.2 in /home/yolov5test/.local/lib/python3.8/site-packages (from kats) (1.2)
# Requirement already satisfied: seaborn>=0.11.1 in /home/yolov5test/.local/lib/python3.8/site-packages (from kats) (0.11.1)
# Requirement already satisfied: statsmodels>=0.12.2 in /home/yolov5test/.local/lib/python3.8/site-packages (from kats) (0.12.2)
# Requirement already satisfied: torch>=1.8.1 in /home/yolov5test/.local/lib/python3.8/site-packages (from kats) (1.9.0)
# Requirement already satisfied: tqdm>=4.36.1 in /home/yolov5test/.local/lib/python3.8/site-packages (from kats) (4.61.2)
# Requirement already satisfied: Cython>=0.22 in /home/yolov5test/.local/lib/python3.8/site-packages (from fbprophet==0.7->kats) (0.29.24)
# Collecting cmdstanpy==0.9.5
#   Downloading https://mirrors.aliyun.com/pypi/packages/e3/e2/204c9c6beaf9e05ad28bd589c154afff35dffa6166d76841d3c0dec6c1e3/cmdstanpy-0.9.5-py3-none-any.whl (37 kB)
# Collecting pymeeus<=1,>=0.3.13
#   Downloading https://mirrors.aliyun.com/pypi/packages/c7/ff/0f0a0becf088281c6bc6c75b7d7c03a2481d486ef6cc7c8899bbcab0a88d/PyMeeus-0.5.11.tar.gz (5.4 MB)
#      |████████████████████████████████| 5.4 MB 8.4 MB/s eta 0:00:01
# Requirement already satisfied: pytz>=2014.10 in /usr/lib/python3/dist-packages (from convertdate>=2.1.2->kats) (2019.3)
# Collecting hijri-converter
#   Downloading https://mirrors.aliyun.com/pypi/packages/f9/17/1b7314a44dd60b032ed0939112c4dfadfa715ab248d986e8006e090feb39/hijri_converter-2.2.0-py3-none-any.whl (14 kB)
# Requirement already satisfied: six in /home/yolov5test/.local/lib/python3.8/site-packages (from holidays>=0.10.2->kats) (1.15.0)
# Collecting korean-lunar-calendar
#   Downloading https://mirrors.aliyun.com/pypi/packages/15/41/aa426a4a9141afd8e7f5c8312bb59d5693274f3f7b34e73bdce4ee48b4c1/korean_lunar_calendar-0.2.1-py3-none-any.whl (8.0 kB)
# Collecting ephem>=3.7.5.3
#   Downloading https://mirrors.aliyun.com/pypi/packages/99/36/7ad6989b8832905122543b32d49ec5e6ece083b5f8ea8065d371b05ac4b1/ephem-4.0.0.2-cp38-cp38-manylinux2010_x86_64.whl (1.2 MB)
#      |████████████████████████████████| 1.2 MB 10.1 MB/s eta 0:00:01
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/yolov5test/.local/lib/python3.8/site-packages (from matplotlib>=2.0.0->kats) (1.3.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/lib/python3/dist-packages (from matplotlib>=2.0.0->kats) (7.0.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /home/yolov5test/.local/lib/python3.8/site-packages (from matplotlib>=2.0.0->kats) (2.4.7)
# Requirement already satisfied: cycler>=0.10 in /home/yolov5test/.local/lib/python3.8/site-packages (from matplotlib>=2.0.0->kats) (0.10.0)
# Collecting llvmlite<0.37,>=0.36.0rc1
#   Downloading https://mirrors.aliyun.com/pypi/packages/28/7c/a0b7cc59f4c2d46347f46a2aa687cb96d3fe45a6750cd1fc7e69541a5462/llvmlite-0.36.0-cp38-cp38-manylinux2010_x86_64.whl (25.3 MB)
#      |████████████████████████████████| 25.3 MB 5.9 MB/s eta 0:00:01     |█████▌                          | 4.4 MB 13.1 MB/s eta 0:00:02
# Requirement already satisfied: setuptools in /home/yolov5test/.local/lib/python3.8/site-packages (from numba>=0.52.0->kats) (57.4.0)
# Collecting tenacity>=6.2.0
#   Downloading https://mirrors.aliyun.com/pypi/packages/f2/a5/f86bc8d67c979020438c8559cc70cfe3a1643fd160d35e09c9cca6a09189/tenacity-8.0.1-py3-none-any.whl (24 kB)
# Requirement already satisfied: scipy in /home/yolov5test/.local/lib/python3.8/site-packages (from pymannkendall>=1.4.1->kats) (1.7.0)
# Requirement already satisfied: joblib>=0.11 in /home/yolov5test/.local/lib/python3.8/site-packages (from scikit-learn>+0.24.2->kats) (1.0.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/yolov5test/.local/lib/python3.8/site-packages (from scikit-learn>+0.24.2->kats) (2.2.0)
# Requirement already satisfied: patsy>=0.5 in /home/yolov5test/.local/lib/python3.8/site-packages (from statsmodels>=0.12.2->kats) (0.5.1)
# Requirement already satisfied: typing-extensions in /home/yolov5test/.local/lib/python3.8/site-packages (from torch>=1.8.1->kats) (3.7.4.3)
# Collecting botorch==0.5.0
#   Downloading https://mirrors.aliyun.com/pypi/packages/28/c4/21f596cd9e22abc33861a3314e0003002a1e948eddcb377289d0354d5e32/botorch-0.5.0-py3-none-any.whl (475 kB)
#      |████████████████████████████████| 475 kB 1.8 MB/s eta 0:00:01
# Requirement already satisfied: typeguard in /home/yolov5test/.local/lib/python3.8/site-packages (from ax-platform->kats) (2.12.1)
# Requirement already satisfied: jinja2 in /home/yolov5test/.local/lib/python3.8/site-packages (from ax-platform->kats) (3.0.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/yolov5test/.local/lib/python3.8/site-packages (from jinja2->ax-platform->kats) (2.0.1)
# Building wheels for collected packages: kats, fbprophet, pymeeus
#   Building wheel for kats (setup.py) ... done
#   Created wheel for kats: filename=kats-0.1.0-py3-none-any.whl size=286608 sha256=fadb32f61ff0ca6169821a990205680b864a12dd6912f55940b4943d7c9bb124
#   Stored in directory: /home/yolov5test/.cache/pip/wheels/d2/23/ed/8ef1274d6e0d6cd6fecacd8d7e585489d6856c11c92bdb5ccb
#   Building wheel for fbprophet (setup.py) ... error
#   ERROR: Command errored out with exit status 1:
#    command: /usr/bin/python3 -u -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'/tmp/pip-install-kqv23l5m/fbprophet_21cdd2a94141494cb6f954ba9494c9f3/setup.py'"'"'; __file__='"'"'/tmp/pip-install-kqv23l5m/fbprophet_21cdd2a94141494cb6f954ba9494c9f3/setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' bdist_wheel -d /tmp/pip-wheel-_cxdxgms
#        cwd: /tmp/pip-install-kqv23l5m/fbprophet_21cdd2a94141494cb6f954ba9494c9f3/
#   Complete output (44 lines):
#   running bdist_wheel
#   running build
#   running build_py
#   creating build
#   creating build/lib
#   creating build/lib/fbprophet
#   creating build/lib/fbprophet/stan_model
#   Traceback (most recent call last):
#     File "<string>", line 1, in <module>
#     File "/tmp/pip-install-kqv23l5m/fbprophet_21cdd2a94141494cb6f954ba9494c9f3/setup.py", line 122, in <module>
#       setup(
#     File "/home/yolov5test/.local/lib/python3.8/site-packages/setuptools/__init__.py", line 153, in setup
#       return distutils.core.setup(**attrs)
#     File "/usr/lib/python3.8/distutils/core.py", line 148, in setup
#       dist.run_commands()
#     File "/usr/lib/python3.8/distutils/dist.py", line 966, in run_commands
#       self.run_command(cmd)
#     File "/usr/lib/python3.8/distutils/dist.py", line 985, in run_command
#       cmd_obj.run()
#     File "/home/yolov5test/.local/lib/python3.8/site-packages/wheel/bdist_wheel.py", line 299, in run
#       self.run_command('build')
#     File "/usr/lib/python3.8/distutils/cmd.py", line 313, in run_command
#       self.distribution.run_command(command)
#     File "/usr/lib/python3.8/distutils/dist.py", line 985, in run_command
#       cmd_obj.run()
#     File "/usr/lib/python3.8/distutils/command/build.py", line 135, in run
#       self.run_command(cmd_name)
#     File "/usr/lib/python3.8/distutils/cmd.py", line 313, in run_command
#       self.distribution.run_command(command)
#     File "/usr/lib/python3.8/distutils/dist.py", line 985, in run_command
#       cmd_obj.run()
#     File "/tmp/pip-install-kqv23l5m/fbprophet_21cdd2a94141494cb6f954ba9494c9f3/setup.py", line 48, in run
#       build_models(target_dir)
#     File "/tmp/pip-install-kqv23l5m/fbprophet_21cdd2a94141494cb6f954ba9494c9f3/setup.py", line 36, in build_models
#       from fbprophet.models import StanBackendEnum
#     File "/tmp/pip-install-kqv23l5m/fbprophet_21cdd2a94141494cb6f954ba9494c9f3/fbprophet/__init__.py", line 8, in <module>
#       from fbprophet.forecaster import Prophet
#     File "/tmp/pip-install-kqv23l5m/fbprophet_21cdd2a94141494cb6f954ba9494c9f3/fbprophet/forecaster.py", line 17, in <module>
#       from fbprophet.make_holidays import get_holiday_names, make_holidays_df
#     File "/tmp/pip-install-kqv23l5m/fbprophet_21cdd2a94141494cb6f954ba9494c9f3/fbprophet/make_holidays.py", line 14, in <module>
#       import fbprophet.hdays as hdays_part2
#     File "/tmp/pip-install-kqv23l5m/fbprophet_21cdd2a94141494cb6f954ba9494c9f3/fbprophet/hdays.py", line 13, in <module>
#       from convertdate.islamic import from_gregorian, to_gregorian
#   ModuleNotFoundError: No module named 'convertdate'
#   ----------------------------------------
#   ERROR: Failed building wheel for fbprophet
#   Running setup.py clean for fbprophet
#   Building wheel for pymeeus (setup.py) ... done
#   Created wheel for pymeeus: filename=PyMeeus-0.5.11-py3-none-any.whl size=730983 sha256=67f8013ab938119da443c20093eb2f314f2b666121b1d766ecef470b08c3fcef
#   Stored in directory: /home/yolov5test/.cache/pip/wheels/80/49/b4/c13407efd3445b5d0969189e345caf25e7111540380800fafc
# Successfully built kats pymeeus
# Failed to build fbprophet
# Installing collected packages: pymeeus, tenacity, korean-lunar-calendar, hijri-converter, gpytorch, ephem, convertdate, pystan, plotly, LunarCalendar, llvmlite, holidays, cmdstanpy, botorch, pymannkendall, numba, fbprophet, ax-platform, kats
#     Running setup.py install for fbprophet ... done
#   DEPRECATION: fbprophet was installed using the legacy 'setup.py install' method, because a wheel could not be built for it. A possible replacement is to fix the wheel build issue reported above. You can find discussion regarding this at https://github.com/pypa/pip/issues/8368.
# Successfully installed LunarCalendar-0.0.9 ax-platform-0.2.1 botorch-0.5.0 cmdstanpy-0.9.5 convertdate-2.3.2 ephem-4.0.0.2 fbprophet-0.7 gpytorch-1.5.0 hijri-converter-2.2.0 holidays-0.11.2 kats-0.1.0 korean-lunar-calendar-0.2.1 llvmlite-0.36.0 numba-0.53.1 plotly-5.2.1 pymannkendall-1.4.2 pymeeus-0.5.11 pystan-2.19.1.1 tenacity-8.0.1
# WARNING: You are using pip version 21.2.2; however, version 21.2.4 is available.
# You should consider upgrading via the '/usr/bin/python3 -m pip install --upgrade pip' command.

# %% [markdown]
# Forcast test

# %%
import pandas as pd

from kats.consts import TimeSeriesData
from kats.models.prophet import ProphetModel, ProphetParams

# take `air_passengers` data as an example
air_passengers_df = pd.read_csv(
    "./kats/data/air_passengers.csv",
    header=0,
    names=["time", "passengers"],
)

# convert to TimeSeriesData object
air_passengers_ts = TimeSeriesData(air_passengers_df)

# create a model param instance
params = ProphetParams(seasonality_mode='multiplicative') # additive mode gives worse results

# create a prophet model instance
m = ProphetModel(air_passengers_ts, params)

# fit model simply by calling m.fit()
m.fit()

# make prediction for next 30 month
fcst = m.predict(steps=30, freq="MS")
# Out:
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# Initial log joint probability = -2.46502
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       99       501.449     0.0176543       240.422       0.649           1      137
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      199       503.353    0.00108498       90.0341      0.3062      0.3062      271
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      299       503.446   0.000140197        80.679           1           1      396
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      303       503.467   9.96247e-05       114.472   7.079e-07       0.001      451  LS failed, Hessian reset
#      359       503.486   8.82342e-09       72.6598    0.004982           1      538
# Optimization terminated normally:
#   Convergence detected: absolute parameter change was below tolerance
